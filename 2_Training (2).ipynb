# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** Image caption model uses an encoder-decoder architecture, where encoder extrancts features of a given image, and decoder generates captions based on the the features from the encoder. Encoder uses a CNN architecutre because CNN is a state of the art for image based task, and Decoder uses LSTM not the plain RNN. Embed size is chosen as 256, and hidden size is 512 referring to the paper. Vocabulary count threshold is chosen to be 5 in order to igore infrequently shown words.
#
# (Optional) Task #2
#
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** I left the given transform_train as it is because the trained model gives a good result. RandomCrop with 224 is necessary to ensure the size of images to be the same size. RandomHorizontalFlip with 0.5 probability auguments training image data so that the model can be trained on more dataset. Normalize the images with the same average and standard deviation value as the training dataset (ImageNet) to make them same as the pre-trained model's distribution.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** Only the weights in the embedding layer of the encoder and all the weight of the decoder are trained while the other parameters of the encoder will not be trained because a pre-trained model is used.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** The paper recommends to use SGD. I choose Adam optimizer which is a SGD.

# %%
import torch

import gc

gc.collect()

torch.cuda.empty_cache()

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # import torch
# import torch.nn as nn
# from torchvision import transforms
# import sys
# sys.path.append('/opt/cocoapi/PythonAPI')
# from pycocotools.coco import COCO
# from data_loader import get_loader
# from model import EncoderCNN, DecoderRNN
# import math
#
#
# ## TODO #1: Select appropriate values for the Python variables below.
# batch_size = 32         # batch size
# vocab_threshold = 5        # minimum word count threshold
# vocab_from_file = True   # if True, load existing vocab file
# embed_size = 256           # dimensionality of image and word embeddings
# hidden_size = 512          # number of features in hidden state of the RNN decoder
# num_epochs = 3             # number of training epochs
# save_every = 1             # determines frequency of saving model weights
# print_every = 100          # determines window for printing average loss
# log_file = 'training_log.txt'       # name of file with saved training loss and perplexity
#
# # (Optional) TODO #2: Amend the image transform below.
# transform_train = transforms.Compose([
#     transforms.Resize(256),                          # smaller edge of image resized to 256
#     transforms.RandomCrop(224),                      # get 224x224 crop from random location
#     transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
#     transforms.ToTensor(),                           # convert the PIL Image to a tensor
#     transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
#                          (0.229, 0.224, 0.225))])
#
# # Build data loader.
# data_loader = get_loader(transform=transform_train,
#                          mode='train',
#                          batch_size=batch_size,
#                          vocab_threshold=vocab_threshold,
#                          vocab_from_file=vocab_from_file)
#
# # The size of the vocabulary.
# vocab_size = len(data_loader.dataset.vocab)
#
# # Initialize the encoder and decoder.
# encoder = EncoderCNN(embed_size)
# decoder = DecoderRNN(embed_size, hidden_size, vocab_size)
#
# # Move models to GPU if CUDA is available.
# device = torch.device("cuda")
# encoder.to(device)
# decoder.to(device)
#
# # Define the loss function.
# criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()
#
# # TODO #3: Specify the learnable parameters of the model.
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
#
# # TODO #4: Define the optimizer.
# optimizer = torch.optim.Adam(params, lr=0.003)
#
# # Set the total number of training steps per epoch.
# total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys

# !pip install nltk
import nltk
nltk.download('punkt')

sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 16         # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True   # if True, load existing vocab file
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params =  list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=0.001)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.6/site-packages (3.2.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from nltk) (1.11.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=1.12s)
# creating index...
#   0%|          | 716/414113 [00:00<02:04, 3333.80it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:44<00:00, 3971.72it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
# response = requests.request("GET", 
#                             "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
#                             headers={"Metadata-Flavor":"Google"})


# from workspace_utils import keep_awake

# for i in keep_awake(range(5)):  
#    #anything that happens inside this loop will keep the workspace active
#    # do iteration with lots of work here
for epoch in range(1, num_epochs+1):

    for i_step in range(1, total_step+1):

        # if time.time() - old_time > 60:
        #     old_time = time.time()
        #     requests.request("POST", 
        #                      "https://nebula.udacity.com/api/v1/remote/keep-alive", 
        #                      headers={'Authorization': "STAR " + response.text})

        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler

        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)

        # print(captions)

        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()

        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)

        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))

        # Backward pass.
        loss.backward()

        # Update the parameters in the optimizer.
        optimizer.step()

        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))

        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()

        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()

        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)

    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-sagemaker-nbJob-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-sagemaker-nbJob-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/25883], Loss: 4.2590, Perplexity: 70.7406
# Epoch [1/3], Step [200/25883], Loss: 3.6932, Perplexity: 40.17171
# Epoch [1/3], Step [300/25883], Loss: 3.5759, Perplexity: 35.72816
# Epoch [1/3], Step [400/25883], Loss: 3.8626, Perplexity: 47.59074
# Epoch [1/3], Step [500/25883], Loss: 3.4404, Perplexity: 31.1995
# Epoch [1/3], Step [600/25883], Loss: 3.4688, Perplexity: 32.0991
# Epoch [1/3], Step [700/25883], Loss: 3.2141, Perplexity: 24.88100
# Epoch [1/3], Step [800/25883], Loss: 3.2538, Perplexity: 25.8889
# Epoch [1/3], Step [900/25883], Loss: 3.3755, Perplexity: 29.2398
# Epoch [1/3], Step [1000/25883], Loss: 3.0553, Perplexity: 21.2269
# Epoch [1/3], Step [1100/25883], Loss: 3.0001, Perplexity: 20.0867
# Epoch [1/3], Step [1200/25883], Loss: 3.2455, Perplexity: 25.6737
# Epoch [1/3], Step [1300/25883], Loss: 2.8179, Perplexity: 16.7421
# Epoch [1/3], Step [1400/25883], Loss: 3.0688, Perplexity: 21.5150
# Epoch [1/3], Step [1500/25883], Loss: 3.7193, Perplexity: 41.23530
# Epoch [1/3], Step [1600/25883], Loss: 3.5719, Perplexity: 35.5838
# Epoch [1/3], Step [1700/25883], Loss: 2.6684, Perplexity: 14.4175
# Epoch [1/3], Step [1800/25883], Loss: 3.3388, Perplexity: 28.1846
# Epoch [1/3], Step [1900/25883], Loss: 3.0249, Perplexity: 20.5928
# Epoch [1/3], Step [2000/25883], Loss: 3.1890, Perplexity: 24.2644
# Epoch [1/3], Step [2100/25883], Loss: 2.9195, Perplexity: 18.5327
# Epoch [1/3], Step [2200/25883], Loss: 2.2138, Perplexity: 9.15083
# Epoch [1/3], Step [2300/25883], Loss: 3.7448, Perplexity: 42.3004
# Epoch [1/3], Step [2400/25883], Loss: 2.7760, Perplexity: 16.0545
# Epoch [1/3], Step [2500/25883], Loss: 2.8135, Perplexity: 16.6685
# Epoch [1/3], Step [2600/25883], Loss: 3.2204, Perplexity: 25.0393
# Epoch [1/3], Step [2700/25883], Loss: 2.7741, Perplexity: 16.0237
# Epoch [1/3], Step [2800/25883], Loss: 2.5720, Perplexity: 13.0915
# Epoch [1/3], Step [2900/25883], Loss: 3.0203, Perplexity: 20.4974
# Epoch [1/3], Step [3000/25883], Loss: 2.9210, Perplexity: 18.5595
# Epoch [1/3], Step [3100/25883], Loss: 4.5306, Perplexity: 92.8170
# Epoch [1/3], Step [3200/25883], Loss: 2.5791, Perplexity: 13.1848
# Epoch [1/3], Step [3300/25883], Loss: 3.0210, Perplexity: 20.5114
# Epoch [1/3], Step [3400/25883], Loss: 2.6933, Perplexity: 14.7803
# Epoch [1/3], Step [3500/25883], Loss: 2.9612, Perplexity: 19.3206
# Epoch [1/3], Step [3600/25883], Loss: 2.5134, Perplexity: 12.3473
# Epoch [1/3], Step [3700/25883], Loss: 2.0278, Perplexity: 7.59765
# Epoch [1/3], Step [3800/25883], Loss: 2.6934, Perplexity: 14.7824
# Epoch [1/3], Step [3900/25883], Loss: 2.5247, Perplexity: 12.4873
# Epoch [1/3], Step [4000/25883], Loss: 2.5259, Perplexity: 12.5025
# Epoch [1/3], Step [4100/25883], Loss: 2.9614, Perplexity: 19.3245
# Epoch [1/3], Step [4200/25883], Loss: 2.2819, Perplexity: 9.79535
# Epoch [1/3], Step [4300/25883], Loss: 3.0130, Perplexity: 20.3475
# Epoch [1/3], Step [4400/25883], Loss: 3.4296, Perplexity: 30.8656
# Epoch [1/3], Step [4500/25883], Loss: 2.4669, Perplexity: 11.7858
# Epoch [1/3], Step [4600/25883], Loss: 2.8641, Perplexity: 17.5341
# Epoch [1/3], Step [4700/25883], Loss: 2.4606, Perplexity: 11.7115
# Epoch [1/3], Step [4800/25883], Loss: 2.0996, Perplexity: 8.16310
# Epoch [1/3], Step [4900/25883], Loss: 2.1269, Perplexity: 8.388631
# Epoch [1/3], Step [5000/25883], Loss: 2.2256, Perplexity: 9.25900
# Epoch [1/3], Step [5100/25883], Loss: 3.0189, Perplexity: 20.4692
# Epoch [1/3], Step [5200/25883], Loss: 3.6249, Perplexity: 37.5217
# Epoch [1/3], Step [5300/25883], Loss: 2.6692, Perplexity: 14.4280
# Epoch [1/3], Step [5400/25883], Loss: 2.0388, Perplexity: 7.68169
# Epoch [1/3], Step [5500/25883], Loss: 2.5637, Perplexity: 12.9840
# Epoch [1/3], Step [5600/25883], Loss: 2.6088, Perplexity: 13.5831
# Epoch [1/3], Step [5700/25883], Loss: 2.9403, Perplexity: 18.9214
# Epoch [1/3], Step [5800/25883], Loss: 2.6968, Perplexity: 14.8323
# Epoch [1/3], Step [5900/25883], Loss: 2.1539, Perplexity: 8.61808
# Epoch [1/3], Step [6000/25883], Loss: 2.4574, Perplexity: 11.6747
# Epoch [1/3], Step [6100/25883], Loss: 2.2492, Perplexity: 9.48025
# Epoch [1/3], Step [6200/25883], Loss: 3.0369, Perplexity: 20.8414
# Epoch [1/3], Step [6300/25883], Loss: 2.2404, Perplexity: 9.39757
# Epoch [1/3], Step [6400/25883], Loss: 2.6143, Perplexity: 13.6577
# Epoch [1/3], Step [6500/25883], Loss: 3.5046, Perplexity: 33.2665
# Epoch [1/3], Step [6600/25883], Loss: 2.2991, Perplexity: 9.96518
# Epoch [1/3], Step [6700/25883], Loss: 3.1658, Perplexity: 23.7086
# Epoch [1/3], Step [6800/25883], Loss: 2.1535, Perplexity: 8.61473
# Epoch [1/3], Step [6900/25883], Loss: 2.0160, Perplexity: 7.50820
# Epoch [1/3], Step [7000/25883], Loss: 2.1979, Perplexity: 9.00610
# Epoch [1/3], Step [7100/25883], Loss: 1.9836, Perplexity: 7.26890
# Epoch [1/3], Step [7200/25883], Loss: 2.6876, Perplexity: 14.6964
# Epoch [1/3], Step [7300/25883], Loss: 2.5527, Perplexity: 12.8420
# Epoch [1/3], Step [7400/25883], Loss: 2.8041, Perplexity: 16.5127
# Epoch [1/3], Step [7500/25883], Loss: 2.6294, Perplexity: 13.8658
# Epoch [1/3], Step [7600/25883], Loss: 3.5063, Perplexity: 33.3245
# Epoch [1/3], Step [7700/25883], Loss: 2.2387, Perplexity: 9.38071
# Epoch [1/3], Step [7800/25883], Loss: 2.5763, Perplexity: 13.1482
# Epoch [1/3], Step [7900/25883], Loss: 2.6412, Perplexity: 14.0295
# Epoch [1/3], Step [8000/25883], Loss: 2.2146, Perplexity: 9.15786
# Epoch [1/3], Step [8100/25883], Loss: 2.5087, Perplexity: 12.2892
# Epoch [1/3], Step [8200/25883], Loss: 2.1844, Perplexity: 8.88568
# Epoch [1/3], Step [8300/25883], Loss: 2.8022, Perplexity: 16.4809
# Epoch [1/3], Step [8400/25883], Loss: 2.7015, Perplexity: 14.9022
# Epoch [1/3], Step [8500/25883], Loss: 2.2819, Perplexity: 9.79565
# Epoch [1/3], Step [8600/25883], Loss: 2.6072, Perplexity: 13.5606
# Epoch [1/3], Step [8700/25883], Loss: 2.4740, Perplexity: 11.8698
# Epoch [1/3], Step [8800/25883], Loss: 3.0729, Perplexity: 21.6052
# Epoch [1/3], Step [8900/25883], Loss: 2.6035, Perplexity: 13.5105
# Epoch [1/3], Step [9000/25883], Loss: 2.2159, Perplexity: 9.16956
# Epoch [1/3], Step [9100/25883], Loss: 2.4824, Perplexity: 11.9704
# Epoch [1/3], Step [9200/25883], Loss: 2.0102, Perplexity: 7.46456
# Epoch [1/3], Step [9300/25883], Loss: 2.7191, Perplexity: 15.1662
# Epoch [1/3], Step [9400/25883], Loss: 2.5498, Perplexity: 12.8051
# Epoch [1/3], Step [9500/25883], Loss: 2.6035, Perplexity: 13.5110
# Epoch [1/3], Step [9600/25883], Loss: 2.7328, Perplexity: 15.3752
# Epoch [1/3], Step [9700/25883], Loss: 2.1355, Perplexity: 8.46141
# Epoch [1/3], Step [9800/25883], Loss: 1.9443, Perplexity: 6.98901
# Epoch [1/3], Step [9900/25883], Loss: 2.4490, Perplexity: 11.5772
# Epoch [1/3], Step [10000/25883], Loss: 2.2043, Perplexity: 9.0639
# Epoch [1/3], Step [10100/25883], Loss: 2.0990, Perplexity: 8.15775
# Epoch [1/3], Step [10200/25883], Loss: 2.3267, Perplexity: 10.2443
# Epoch [1/3], Step [10300/25883], Loss: 2.3809, Perplexity: 10.8142
# Epoch [1/3], Step [10400/25883], Loss: 2.5487, Perplexity: 12.7902
# Epoch [1/3], Step [10500/25883], Loss: 2.9648, Perplexity: 19.3918
# Epoch [1/3], Step [10600/25883], Loss: 2.4568, Perplexity: 11.6674
# Epoch [1/3], Step [10700/25883], Loss: 2.2180, Perplexity: 9.18898
# Epoch [1/3], Step [10800/25883], Loss: 2.1414, Perplexity: 8.51174
# Epoch [1/3], Step [10900/25883], Loss: 2.2623, Perplexity: 9.60565
# Epoch [1/3], Step [11000/25883], Loss: 2.7162, Perplexity: 15.1230
# Epoch [1/3], Step [11100/25883], Loss: 2.4806, Perplexity: 11.9490
# Epoch [1/3], Step [11200/25883], Loss: 1.8495, Perplexity: 6.35653
# Epoch [1/3], Step [11300/25883], Loss: 2.3209, Perplexity: 10.1848
# Epoch [1/3], Step [11400/25883], Loss: 2.5682, Perplexity: 13.0421
# Epoch [1/3], Step [11500/25883], Loss: 2.5678, Perplexity: 13.0366
# Epoch [1/3], Step [11600/25883], Loss: 2.7458, Perplexity: 15.5767
# Epoch [1/3], Step [11700/25883], Loss: 2.6288, Perplexity: 13.8569
# Epoch [1/3], Step [11800/25883], Loss: 2.3872, Perplexity: 10.8830
# Epoch [1/3], Step [11900/25883], Loss: 2.8275, Perplexity: 16.9025
# Epoch [1/3], Step [12000/25883], Loss: 2.3843, Perplexity: 10.8511
# Epoch [1/3], Step [12100/25883], Loss: 1.9417, Perplexity: 6.97052
# Epoch [1/3], Step [12200/25883], Loss: 2.3098, Perplexity: 10.0727
# Epoch [1/3], Step [12300/25883], Loss: 2.0633, Perplexity: 7.87214
# Epoch [1/3], Step [12400/25883], Loss: 2.2749, Perplexity: 9.72667
# Epoch [1/3], Step [12500/25883], Loss: 2.4061, Perplexity: 11.0909
# Epoch [1/3], Step [12600/25883], Loss: 2.4351, Perplexity: 11.4168
# Epoch [1/3], Step [12700/25883], Loss: 1.9798, Perplexity: 7.24125
# Epoch [1/3], Step [12800/25883], Loss: 2.1083, Perplexity: 8.23465
# Epoch [1/3], Step [12900/25883], Loss: 2.4747, Perplexity: 11.8780
# Epoch [1/3], Step [13000/25883], Loss: 2.7038, Perplexity: 14.9364
# Epoch [1/3], Step [13100/25883], Loss: 2.2830, Perplexity: 9.80651
# Epoch [1/3], Step [13200/25883], Loss: 2.2991, Perplexity: 9.96483
# Epoch [1/3], Step [13300/25883], Loss: 2.4062, Perplexity: 11.0912
# Epoch [1/3], Step [13400/25883], Loss: 2.2301, Perplexity: 9.30088
# Epoch [1/3], Step [13500/25883], Loss: 2.1230, Perplexity: 8.35649
# Epoch [1/3], Step [13600/25883], Loss: 2.3328, Perplexity: 10.3068
# Epoch [1/3], Step [13700/25883], Loss: 2.1917, Perplexity: 8.95087
# Epoch [1/3], Step [13800/25883], Loss: 2.3242, Perplexity: 10.21821
# Epoch [1/3], Step [13900/25883], Loss: 2.9430, Perplexity: 18.9728
# Epoch [1/3], Step [14000/25883], Loss: 2.3440, Perplexity: 10.4233
# Epoch [1/3], Step [14100/25883], Loss: 2.1749, Perplexity: 8.80113
# Epoch [1/3], Step [14200/25883], Loss: 2.4708, Perplexity: 11.8316
# Epoch [1/3], Step [14300/25883], Loss: 2.2481, Perplexity: 9.46982
# Epoch [1/3], Step [14400/25883], Loss: 2.6336, Perplexity: 13.9236
# Epoch [1/3], Step [14500/25883], Loss: 2.3741, Perplexity: 10.7417
# Epoch [1/3], Step [14600/25883], Loss: 1.9652, Perplexity: 7.13659
# Epoch [1/3], Step [14700/25883], Loss: 2.5625, Perplexity: 12.9679
# Epoch [1/3], Step [14800/25883], Loss: 2.1856, Perplexity: 8.89633
# Epoch [1/3], Step [14900/25883], Loss: 2.0506, Perplexity: 7.77299
# Epoch [1/3], Step [15000/25883], Loss: 2.2081, Perplexity: 9.09836
# Epoch [1/3], Step [15100/25883], Loss: 2.2631, Perplexity: 9.61298
# Epoch [1/3], Step [15200/25883], Loss: 2.5551, Perplexity: 12.8720
# Epoch [1/3], Step [15300/25883], Loss: 2.6734, Perplexity: 14.4884
# Epoch [1/3], Step [15400/25883], Loss: 2.2639, Perplexity: 9.62105
# Epoch [1/3], Step [15500/25883], Loss: 1.8956, Perplexity: 6.65620
# Epoch [1/3], Step [15600/25883], Loss: 2.0589, Perplexity: 7.83757
# Epoch [1/3], Step [15700/25883], Loss: 2.6035, Perplexity: 13.5104
# Epoch [1/3], Step [15800/25883], Loss: 2.4977, Perplexity: 12.1545
# Epoch [1/3], Step [15900/25883], Loss: 2.4936, Perplexity: 12.1046
# Epoch [1/3], Step [16000/25883], Loss: 2.1953, Perplexity: 8.98301
# Epoch [1/3], Step [16100/25883], Loss: 2.3479, Perplexity: 10.4639
# Epoch [1/3], Step [16200/25883], Loss: 1.9695, Perplexity: 7.16736
# Epoch [1/3], Step [16300/25883], Loss: 2.7876, Perplexity: 16.2428
# Epoch [1/3], Step [16400/25883], Loss: 2.4389, Perplexity: 11.4601
# Epoch [1/3], Step [16500/25883], Loss: 2.2034, Perplexity: 9.05590
# Epoch [1/3], Step [16600/25883], Loss: 2.3734, Perplexity: 10.7340
# Epoch [1/3], Step [16700/25883], Loss: 1.9572, Perplexity: 7.07942
# Epoch [1/3], Step [16800/25883], Loss: 2.1464, Perplexity: 8.55364
# Epoch [1/3], Step [16900/25883], Loss: 2.4854, Perplexity: 12.0059
# Epoch [1/3], Step [17000/25883], Loss: 2.3725, Perplexity: 10.7240
# Epoch [1/3], Step [17100/25883], Loss: 2.2216, Perplexity: 9.22252
# Epoch [1/3], Step [17200/25883], Loss: 2.4385, Perplexity: 11.4556
# Epoch [1/3], Step [17300/25883], Loss: 2.5646, Perplexity: 12.9959
# Epoch [1/3], Step [17400/25883], Loss: 2.5486, Perplexity: 12.7896
# Epoch [1/3], Step [17500/25883], Loss: 2.4607, Perplexity: 11.7135
# Epoch [1/3], Step [17600/25883], Loss: 2.2721, Perplexity: 9.69935
# Epoch [1/3], Step [17700/25883], Loss: 2.2915, Perplexity: 9.88998
# Epoch [1/3], Step [17800/25883], Loss: 2.0644, Perplexity: 7.88075
# Epoch [1/3], Step [17900/25883], Loss: 2.7023, Perplexity: 14.9145
# Epoch [1/3], Step [18000/25883], Loss: 1.8639, Perplexity: 6.44863
# Epoch [1/3], Step [18100/25883], Loss: 1.9946, Perplexity: 7.34922
# Epoch [1/3], Step [18200/25883], Loss: 2.0808, Perplexity: 8.01091
# Epoch [1/3], Step [18300/25883], Loss: 2.1363, Perplexity: 8.46846
# Epoch [1/3], Step [18400/25883], Loss: 2.1211, Perplexity: 8.34065
# Epoch [1/3], Step [18500/25883], Loss: 2.2401, Perplexity: 9.39454
# Epoch [1/3], Step [18600/25883], Loss: 2.3422, Perplexity: 10.4036
# Epoch [1/3], Step [18700/25883], Loss: 2.2190, Perplexity: 9.19852
# Epoch [1/3], Step [18800/25883], Loss: 2.1048, Perplexity: 8.20563
# Epoch [1/3], Step [18900/25883], Loss: 2.5332, Perplexity: 12.5937
# Epoch [1/3], Step [19000/25883], Loss: 2.2490, Perplexity: 9.47827
# Epoch [1/3], Step [19100/25883], Loss: 2.2631, Perplexity: 9.61321
# Epoch [1/3], Step [19200/25883], Loss: 2.3754, Perplexity: 10.7557
# Epoch [1/3], Step [19300/25883], Loss: 2.2106, Perplexity: 9.12149
# Epoch [1/3], Step [19400/25883], Loss: 2.5157, Perplexity: 12.3747
# Epoch [1/3], Step [19500/25883], Loss: 2.9780, Perplexity: 19.6478
# Epoch [1/3], Step [19600/25883], Loss: 2.1015, Perplexity: 8.17859
# Epoch [1/3], Step [19700/25883], Loss: 2.0371, Perplexity: 7.66852
# Epoch [1/3], Step [19800/25883], Loss: 2.2749, Perplexity: 9.727258
# Epoch [1/3], Step [19900/25883], Loss: 2.3735, Perplexity: 10.7346
# Epoch [1/3], Step [20000/25883], Loss: 2.0828, Perplexity: 8.02695
# Epoch [1/3], Step [20100/25883], Loss: 2.7165, Perplexity: 15.1275
# Epoch [1/3], Step [20200/25883], Loss: 2.8448, Perplexity: 17.1978
# Epoch [1/3], Step [20300/25883], Loss: 2.6969, Perplexity: 14.8339
# Epoch [1/3], Step [20400/25883], Loss: 2.0411, Perplexity: 7.69905
# Epoch [1/3], Step [20500/25883], Loss: 1.9953, Perplexity: 7.35450
# Epoch [1/3], Step [20600/25883], Loss: 2.4498, Perplexity: 11.5861
# Epoch [1/3], Step [20700/25883], Loss: 2.3799, Perplexity: 10.8036
# Epoch [1/3], Step [20800/25883], Loss: 2.6213, Perplexity: 13.7537
# Epoch [1/3], Step [20900/25883], Loss: 2.1508, Perplexity: 8.59209
# Epoch [1/3], Step [21000/25883], Loss: 2.1071, Perplexity: 8.22428
# Epoch [1/3], Step [21100/25883], Loss: 2.5902, Perplexity: 13.3329
# Epoch [1/3], Step [21200/25883], Loss: 2.3295, Perplexity: 10.2724
# Epoch [1/3], Step [21300/25883], Loss: 2.4794, Perplexity: 11.9342
# Epoch [1/3], Step [21400/25883], Loss: 1.7770, Perplexity: 5.91218
# Epoch [1/3], Step [21500/25883], Loss: 2.5310, Perplexity: 12.5667
# Epoch [1/3], Step [21600/25883], Loss: 2.7243, Perplexity: 15.2457
# Epoch [1/3], Step [21700/25883], Loss: 2.2400, Perplexity: 9.39301
# Epoch [1/3], Step [21800/25883], Loss: 1.9196, Perplexity: 6.81811
# Epoch [1/3], Step [21900/25883], Loss: 2.4975, Perplexity: 12.1520
# Epoch [1/3], Step [22000/25883], Loss: 2.4908, Perplexity: 12.0710
# Epoch [1/3], Step [22100/25883], Loss: 2.4924, Perplexity: 12.0900
# Epoch [1/3], Step [22200/25883], Loss: 2.6167, Perplexity: 13.6904
# Epoch [1/3], Step [22300/25883], Loss: 1.8285, Perplexity: 6.22466
# Epoch [1/3], Step [22400/25883], Loss: 2.3111, Perplexity: 10.0854
# Epoch [1/3], Step [22500/25883], Loss: 2.4511, Perplexity: 11.6010
# Epoch [1/3], Step [22600/25883], Loss: 2.1712, Perplexity: 8.768714
# Epoch [1/3], Step [22700/25883], Loss: 2.0108, Perplexity: 7.469140
# Epoch [1/3], Step [22800/25883], Loss: 2.4246, Perplexity: 11.2981
# Epoch [1/3], Step [22900/25883], Loss: 2.2065, Perplexity: 9.08409
# Epoch [1/3], Step [23000/25883], Loss: 1.8628, Perplexity: 6.44173
# Epoch [1/3], Step [23100/25883], Loss: 2.1259, Perplexity: 8.38023
# Epoch [1/3], Step [23200/25883], Loss: 2.2931, Perplexity: 9.90520
# Epoch [1/3], Step [23300/25883], Loss: 2.2110, Perplexity: 9.12515
# Epoch [1/3], Step [23400/25883], Loss: 2.3272, Perplexity: 10.2494
# Epoch [1/3], Step [23500/25883], Loss: 2.1253, Perplexity: 8.37515
# Epoch [1/3], Step [23600/25883], Loss: 1.8602, Perplexity: 6.42526
# Epoch [1/3], Step [23700/25883], Loss: 2.1056, Perplexity: 8.21238
# Epoch [1/3], Step [23800/25883], Loss: 2.5698, Perplexity: 13.0626
# Epoch [1/3], Step [23900/25883], Loss: 2.9964, Perplexity: 20.0124
# Epoch [1/3], Step [24000/25883], Loss: 2.0517, Perplexity: 7.78125
# Epoch [1/3], Step [24100/25883], Loss: 2.3182, Perplexity: 10.1571
# Epoch [1/3], Step [24200/25883], Loss: 2.0199, Perplexity: 7.53790
# Epoch [1/3], Step [24300/25883], Loss: 2.4471, Perplexity: 11.5548
# Epoch [1/3], Step [24400/25883], Loss: 2.1963, Perplexity: 8.99185
# Epoch [1/3], Step [24500/25883], Loss: 2.5055, Perplexity: 12.2502
# Epoch [1/3], Step [24600/25883], Loss: 2.2141, Perplexity: 9.15282
# Epoch [1/3], Step [24700/25883], Loss: 2.2194, Perplexity: 9.20186
# Epoch [1/3], Step [24800/25883], Loss: 2.4236, Perplexity: 11.2867
# Epoch [1/3], Step [24900/25883], Loss: 2.6307, Perplexity: 13.8839
# Epoch [1/3], Step [25000/25883], Loss: 2.2908, Perplexity: 9.88317
# Epoch [1/3], Step [25100/25883], Loss: 2.2697, Perplexity: 9.67653
# Epoch [1/3], Step [25200/25883], Loss: 2.3490, Perplexity: 10.4755
# Epoch [1/3], Step [25300/25883], Loss: 1.8742, Perplexity: 6.51582
# Epoch [1/3], Step [25400/25883], Loss: 2.2773, Perplexity: 9.75029
# Epoch [1/3], Step [25500/25883], Loss: 2.3376, Perplexity: 10.3568
# Epoch [1/3], Step [25600/25883], Loss: 2.1291, Perplexity: 8.40760
# Epoch [1/3], Step [25700/25883], Loss: 2.5418, Perplexity: 12.70219
# Epoch [1/3], Step [25800/25883], Loss: 2.4358, Perplexity: 11.4255
# Epoch [2/3], Step [100/25883], Loss: 2.1383, Perplexity: 8.4850333
# Epoch [2/3], Step [200/25883], Loss: 2.1512, Perplexity: 8.59550
# Epoch [2/3], Step [300/25883], Loss: 2.0413, Perplexity: 7.70036
# Epoch [2/3], Step [400/25883], Loss: 2.2013, Perplexity: 9.03725
# Epoch [2/3], Step [500/25883], Loss: 2.0405, Perplexity: 7.69453
# Epoch [2/3], Step [600/25883], Loss: 2.0825, Perplexity: 8.02448
# Epoch [2/3], Step [700/25883], Loss: 2.4651, Perplexity: 11.7646
# Epoch [2/3], Step [800/25883], Loss: 2.5383, Perplexity: 12.6583
# Epoch [2/3], Step [900/25883], Loss: 1.9774, Perplexity: 7.22387
# Epoch [2/3], Step [1000/25883], Loss: 2.1544, Perplexity: 8.6226
# Epoch [2/3], Step [1100/25883], Loss: 1.9103, Perplexity: 6.75492
# Epoch [2/3], Step [1200/25883], Loss: 2.4031, Perplexity: 11.0572
# Epoch [2/3], Step [1400/25883], Loss: 2.1234, Perplexity: 8.35982
# Epoch [2/3], Step [1500/25883], Loss: 2.2258, Perplexity: 9.26121
# Epoch [2/3], Step [1600/25883], Loss: 2.4826, Perplexity: 11.9718
# Epoch [2/3], Step [1700/25883], Loss: 1.8287, Perplexity: 6.22604
# Epoch [2/3], Step [1800/25883], Loss: 2.2195, Perplexity: 9.202483
# Epoch [2/3], Step [1900/25883], Loss: 2.3244, Perplexity: 10.2205
# Epoch [2/3], Step [2000/25883], Loss: 2.5956, Perplexity: 13.4051
# Epoch [2/3], Step [2100/25883], Loss: 1.8955, Perplexity: 6.65596
# Epoch [2/3], Step [2200/25883], Loss: 2.5376, Perplexity: 12.6489
# Epoch [2/3], Step [2300/25883], Loss: 2.3295, Perplexity: 10.2732
# Epoch [2/3], Step [2400/25883], Loss: 3.0844, Perplexity: 21.8545
# Epoch [2/3], Step [2500/25883], Loss: 2.2899, Perplexity: 9.87417
# Epoch [2/3], Step [2600/25883], Loss: 2.2910, Perplexity: 9.88539
# Epoch [2/3], Step [2700/25883], Loss: 2.2380, Perplexity: 9.37465
# Epoch [2/3], Step [2730/25883], Loss: 2.0237, Perplexity: 7.56625

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
